# %% [markdown]
# # Sequence Analysis
# Basic analysis of ProteinMPNN-generated sequences can be added here.

# %%
import pandas as pd
# Example: df = pd.read_csv('../results/tables/candidate_metrics.csv')
